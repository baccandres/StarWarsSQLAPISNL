# %%
import pandas as pd
import sys
import os
import dotenv
sys.path.append('../tools')
from getpass import getpass 
import sqlalchemy as alch
#import sqltools as sqt
import requests
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
from getpass import getpass

# %%
analyser = SentimentIntensityAnalyzer()

# %%
passw = getpass("password")
dbName = "Starwars"
connectionData = f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)
# Out:
# password········

# %%
tables = engine.execute("SHOW TABLES"); #working
for i in tables:
    print (i)
# Out:
# ('Character',)
# ('Dialogue',)
# ('Episode',)

# %%
requests.get('http://127.0.0.1:5000/').text #working
# Out:
# 'Ciao Mondo!'

# %%
### GET

# %%
def callAPI(endpoint):
    x = requests.get(f"http://127.0.0.1:5000/{endpoint}").content
    return x

# %%
callAPI('/')
# Out:
# b'Ciao Mondo!'

# %%
def chars_list():
    query = list(engine.execute("""SELECT `name` FROM `Starwars`.`Character`;"""))
    return [i[0] for i in query]

# %%
chars_list()
# Out:
# ['PILOTS',
#  'MASSASSI',
#  'NAVIGATOR',
#  'LUKE',
#  'FIRST',
#  'GREEDO',
#  'TECHNICIAN',
#  'NEEDA',
#  'COMMANDER',
#  'DEATH',
#  'DECK',
#  'GOLD',
#  'BERU',
#  'RED',
#  'GREEN',
#  'RIEEKAN',
#  'ASSISTANT',
#  'ZEV',
#  'HOBBIE',
#  'SCOUT',
#  'GRAY',
#  'BOBA',
#  'CAPTAIN',
#  'LIEUTENANT',
#  'AUNT',
#  'COMMUNICATIONS',
#  'HAN/PILOT',
#  'BIB',
#  'DERLIN',
#  'SENIOR',
#  'CREATURE',
#  'PORKINS',
#  'WILLARD',
#  'LANDO',
#  'GANTRY',
#  'OFFICER',
#  'THREEPIO',
#  'GUARD',
#  'CHIEF',
#  'WOMAN',
#  'OWEN',
#  'IMPERIAL',
#  'HUMAN',
#  'INTERCOM',
#  'DODONNA',
#  'DEAK',
#  'MON',
#  'SHUTTLE',
#  'BEN',
#  'ANNOUNCER',
#  'BOUSHH',
#  'ANAKIN',
#  'CAMIE',
#  'TAGGE',
#  'MOTTI',
#  'LURE',
#  'WALKER',
#  'NINEDENINE',
#  'FIXER',
#  'TRACKING',
#  'BIGGS',
#  'DACK',
#  'PILOT',
#  'JANSON',
#  'ACKBAR',
#  'EMPEROR',
#  'OOLA',
#  'CONTROL',
#  'VEERS',
#  'CONTROLLER',
#  'TRENCH',
#  'MAN',
#  'OZZEL',
#  'TROOPER',
#  'ASTRO-OFFICER',
#  'BUNKER',
#  'SECOND',
#  'VOICE',
#  'YODA',
#  'BASE',
#  'VADER',
#  'PIETT',
#  'REBEL',
#  'HEAD',
#  'STRANGE',
#  'LEIA',
#  'HAN',
#  'WEDGE',
#  'STORMTROOPER',
#  'TARKIN',
#  'Y-WING',
#  'JERJERROD',
#  'JABBA',
#  'MEDICAL',
#  'OPERATOR',
#  'WINGMAN',
#  'GENERAL',
#  'BARTENDER']

# %%
requests.get('http://127.0.0.1:5000/characters').content #
# Out:
# b'[\n  {\n    "Name": "PILOTS"\n  }, \n  {\n    "Name": "MASSASSI"\n  }, \n  {\n    "Name": "NAVIGATOR"\n  }, \n  {\n    "Name": "LUKE"\n  }, \n  {\n    "Name": "FIRST"\n  }, \n  {\n    "Name": "GREEDO"\n  }, \n  {\n    "Name": "TECHNICIAN"\n  }, \n  {\n    "Name": "NEEDA"\n  }, \n  {\n    "Name": "COMMANDER"\n  }, \n  {\n    "Name": "DEATH"\n  }, \n  {\n    "Name": "DECK"\n  }, \n  {\n    "Name": "GOLD"\n  }, \n  {\n    "Name": "BERU"\n  }, \n  {\n    "Name": "RED"\n  }, \n  {\n    "Name": "GREEN"\n  }, \n  {\n    "Name": "RIEEKAN"\n  }, \n  {\n    "Name": "ASSISTANT"\n  }, \n  {\n    "Name": "ZEV"\n  }, \n  {\n    "Name": "HOBBIE"\n  }, \n  {\n    "Name": "SCOUT"\n  }, \n  {\n    "Name": "GRAY"\n  }, \n  {\n    "Name": "BOBA"\n  }, \n  {\n    "Name": "CAPTAIN"\n  }, \n  {\n    "Name": "LIEUTENANT"\n  }, \n  {\n    "Name": "AUNT"\n  }, \n  {\n    "Name": "COMMUNICATIONS"\n  }, \n  {\n    "Name": "HAN/PILOT"\n  }, \n  {\n    "Name": "BIB"\n  }, \n  {\n    "Name": "DERLIN"\n  }, \n  {\n    "Name": "SENIOR"\n  }, \n  {\n    "Name": "CREATURE"\n  }, \n  {\n    "Name": "PORKINS"\n  }, \n  {\n    "Name": "WILLARD"\n  }, \n  {\n    "Name": "LANDO"\n  }, \n  {\n    "Name": "GANTRY"\n  }, \n  {\n    "Name": "OFFICER"\n  }, \n  {\n    "Name": "THREEPIO"\n  }, \n  {\n    "Name": "GUARD"\n  }, \n  {\n    "Name": "CHIEF"\n  }, \n  {\n    "Name": "WOMAN"\n  }, \n  {\n    "Name": "OWEN"\n  }, \n  {\n    "Name": "IMPERIAL"\n  }, \n  {\n    "Name": "HUMAN"\n  }, \n  {\n    "Name": "INTERCOM"\n  }, \n  {\n    "Name": "DODONNA"\n  }, \n  {\n    "Name": "DEAK"\n  }, \n  {\n    "Name": "MON"\n  }, \n  {\n    "Name": "SHUTTLE"\n  }, \n  {\n    "Name": "BEN"\n  }, \n  {\n    "Name": "ANNOUNCER"\n  }, \n  {\n    "Name": "BOUSHH"\n  }, \n  {\n    "Name": "ANAKIN"\n  }, \n  {\n    "Name": "CAMIE"\n  }, \n  {\n    "Name": "TAGGE"\n  }, \n  {\n    "Name": "MOTTI"\n  }, \n  {\n    "Name": "LURE"\n  }, \n  {\n    "Name": "WALKER"\n  }, \n  {\n    "Name": "NINEDENINE"\n  }, \n  {\n    "Name": "FIXER"\n  }, \n  {\n    "Name": "TRACKING"\n  }, \n  {\n    "Name": "BIGGS"\n  }, \n  {\n    "Name": "DACK"\n  }, \n  {\n    "Name": "PILOT"\n  }, \n  {\n    "Name": "JANSON"\n  }, \n  {\n    "Name": "ACKBAR"\n  }, \n  {\n    "Name": "EMPEROR"\n  }, \n  {\n    "Name": "OOLA"\n  }, \n  {\n    "Name": "CONTROL"\n  }, \n  {\n    "Name": "VEERS"\n  }, \n  {\n    "Name": "CONTROLLER"\n  }, \n  {\n    "Name": "TRENCH"\n  }, \n  {\n    "Name": "MAN"\n  }, \n  {\n    "Name": "OZZEL"\n  }, \n  {\n    "Name": "TROOPER"\n  }, \n  {\n    "Name": "ASTRO-OFFICER"\n  }, \n  {\n    "Name": "BUNKER"\n  }, \n  {\n    "Name": "SECOND"\n  }, \n  {\n    "Name": "VOICE"\n  }, \n  {\n    "Name": "YODA"\n  }, \n  {\n    "Name": "BASE"\n  }, \n  {\n    "Name": "VADER"\n  }, \n  {\n    "Name": "PIETT"\n  }, \n  {\n    "Name": "REBEL"\n  }, \n  {\n    "Name": "HEAD"\n  }, \n  {\n    "Name": "STRANGE"\n  }, \n  {\n    "Name": "LEIA"\n  }, \n  {\n    "Name": "HAN"\n  }, \n  {\n    "Name": "WEDGE"\n  }, \n  {\n    "Name": "STORMTROOPER"\n  }, \n  {\n    "Name": "TARKIN"\n  }, \n  {\n    "Name": "Y-WING"\n  }, \n  {\n    "Name": "JERJERROD"\n  }, \n  {\n    "Name": "JABBA"\n  }, \n  {\n    "Name": "MEDICAL"\n  }, \n  {\n    "Name": "OPERATOR"\n  }, \n  {\n    "Name": "WINGMAN"\n  }, \n  {\n    "Name": "GENERAL"\n  }, \n  {\n    "Name": "BARTENDER"\n  }\n]\n'

# %%
def characters_list():
    query = list(engine.execute("SELECT `Name` FROM `Starwars`.`Character`;"))
    lista = [{'Name': i[0]} for i in query]
    return lista

# %%
#chars_list()

# %%
def character_quotes(character):
    query = list(engine.execute(f"""SELECT `Name`, `Dialogue`.`Dialogue`
    FROM `Starwars`.`Character`
    INNER JOIN `Dialogue`
    ON `idCharacter` = `idCharacter`
    WHERE `Name` = '{character}';"""))
    list_ = [{'Quote': i[1]} for i in query]
    return list_

# %%
character_quotes('NAVIGATOR')
# Out:
# [{'Quote': 'Did you hear that?  Theyve shut down the main reactor.  Well be destroyed for sure.  This is madness!'},
#  {'Quote': 'Were doomed!'},
#  {'Quote': 'Therell be no escape for the Princess this time.'},
#  {'Quote': 'Whats that?'},
#  {'Quote': 'I should have known better than to trust the logic of a half-sized thermocapsulary dehousing assister...'},
#  {'Quote': 'Hurry up!  Come with me!  What are you waiting for?!  Get in gear!'},
#  {'Quote': 'Artoo! Artoo-Detoo where are you?'},
#  {'Quote': 'At last!  Where have you been?'},
#  {'Quote': 'Theyre heading in this direction. What are we going to do?  Well be sent to the spice mines of Kessel or smashed into who knows what!'},
#  {'Quote': 'Wait a minute where are you going?'},
#  {'Quote': 'OFFICER The Death Star plans are not in the main computer.'},
#  {'Quote': 'Where are those transmissions you intercepted?'},
#  {'Quote': 'OFFICER We intercepted no transmissions. Aaah...  This is a consular ship. Were on a diplomatic mission.'},
#  {'Quote': 'If this is a consular ship... where is the Ambassador?'},
#  {'Quote': 'Commander tear this ship apart until youve found those plans and bring me the Ambassador.  I want her alive!'},
#  {'Quote': 'There she is! Set for stun!'},
#  {'Quote': 'Shell be all right. Inform Lord Vader we have a prisoner.'},
#  {'Quote': 'Hey youre not permitted in there.  Its restricted. Youll be deactivated for sure..'},
#  {'Quote': 'Dont call me a mindless philosopher you overweight glob of grease!  Now come out before somebody sees you.'},
#  {'Quote': 'Secret mission?  What plans?  What are you talking about?  Im not getting in there!'},
#  {'Quote': 'Im going to regret this.'},
#  {'Quote': 'PILOT There goes another one.'},
#  {'Quote': 'Hold your fire.  There are no life forms.  It must have been short-circuited.'},
#  {'Quote': 'Thats funny the damage doesnt look as bad from out here.'},
#  {'Quote': 'Are you sure this things safe?'},
#  {'Quote': 'Ive told you kids to slow down!'},
#  {'Quote': 'Did I hear a young noise blast through here?'},
#  {'Quote': 'It was just Wormie on another rampage.'},
#  {'Quote': 'Shape it up you guys!...  Biggs?'},
#  {'Quote': 'I didnt know you were back!  When did you get in?'},
#  {'Quote': 'Just now.  I wanted to surprise you hot shot.  I thought youd be here... certainly didnt expect you to be out working. '},
#  {'Quote': 'The Academy didnt change you much... but youre back so soon?  Hey what happened didnt you get your commission?'},
#  {'Quote': 'Of course I got it.  Signed aboard The Rand Ecliptic last week.  First mate Biggs Darklighter at your service...... I just came back to say goodbye to all you unfortunate landlocked simpletons.'},
#  {'Quote': 'I almost forgot.  Theres a battle going on!  Right here in our system.  Come and look!'},
#  {'Quote': 'Not again!  Forget it.'},
#  {'Quote': 'There they are!'},
#  {'Quote': 'Thats no battle hot shot... theyre just sitting there!  Probably a freighter-tanker refueling.'},
#  {'Quote': 'But there was a lot of firing earlier...'},
#  {'Quote': 'Hey easy with those...'},
#  {'Quote': 'Dont worry about it Wormie.'},
#  {'Quote': 'I keep telling you the Rebellion is a long way from here.  I doubt if the Empire would even fight to keep this system.  Believe me Luke this planet is a big hunk of nothing...'},
#  {'Quote': 'Lord Vader I should have known.  Only you could be so bold.  The Imperial Senate will not sit stillfor this when they hear youve attacked a diplomatic...'},
#  {'Quote': 'Dont play games with me Your Highness.  You werent on any mercy mission this time.  You passed directly through a restricted system.  Several transmissions were beamed to this ship by Rebel spies.  I want to know what happened to the plans they sent you.'},
#  {'Quote': 'I dont know what youre talking about.  Im a member of the Imperial Senate on a diplomatic mission to Alderaan...'},
#  {'Quote': 'Youre a part of the Rebel Alliance... and a traitor.  Take her away!'},
#  {'Quote': 'Holding her is dangerous.  If word of this gets out it could generate sympathy for the Rebellion in the senate.'},
#  {'Quote': 'I have traced the Rebel spies to her.  Now she is my only link to find their secret base!'},
#  {'Quote': 'you anything.'},
#  {'Quote': 'Leave that to me.  Send a distress signal and then inform the senate that all aboard were killed!'},
#  {'Quote': 'OFFICER Lord Vader the battle station plans are not aboard this ship!  And no transmissions were made.  An escape pod was jettisoned during the fighting but no life forms were aboard.'},
#  {'Quote': 'She must have hidden the plans in the escape pod.  Send a detachment down to retrieve them.  See to it personally Commander.  Therell be no one to stop us this time.'},
#  {'Quote': 'Yes sir.'},
#  {'Quote': 'How did I get into this mess?  I really dont know how.  We seem to be made to suffer.  Its our lot in life.'},
#  {'Quote': 'Ive got to rest before I fall apart.  My joints are almost frozen. '},
#  {'Quote': 'What a desolate place this is.'},
#  {'Quote': 'Where are you going?'},
#  {'Quote': 'Well Im not going that way.  Its much too rocky.  This way is much easier.'},
#  {'Quote': 'What makes you think there are settlements over there?'},
#  {'Quote': 'Dont get technical with me.'},
#  {'Quote': 'What mission?  What are you talking about?  Ive had just about enough of you!  Go that way!  Youll be malfunctioning within a day you nearsighted scrap pile!'},
#  {'Quote': 'And dont let me catch you following me begging for help because you wont get it.'},
#  {'Quote': 'No more adventures.  Im not going that way.'},
#  {'Quote': 'That malfunctioning little twerp.  This is all his fault!  He tricked me into going this way but hell do no better.'},
#  {'Quote': 'Wait whats that?  A transport!  Im saved!'},
#  {'Quote': 'Over here!  Help!  Please help!'},
#  {'Quote': '... so I cut off my power shut down the afterburners and came in low on Deaks trail.  I was so close I thought I was going to fry my instruments. As it was I busted up the Skyhopper pretty bad.  Uncle Owen was pretty upset.  He grounded me for the rest of the season.  You should have been there... it was fantastic.'},
#  {'Quote': 'You ought to take it a little easy Luke.  You may be the hottest bushpilot this side of Mos Eisley but those little Skyhoppers are dangerous.  Keep it up and one day whammo youre going to be nothing more than a dark spot on the down side of a canyon wall.'},
#  {'Quote': 'Look whos talking.  Now that youve been around those giant starships youre beginning to sound like my uncle. Youve gotten soft in the city...'},
#  {'Quote': 'Ive missed you kid.'},
#  {'Quote': 'Well things havent been the same since you left Biggs.  Its been so...quiet.'},
#  {'Quote': 'Luke I didnt come back just to say goodbye...  I shouldnt tell you this but youre the only one I can trust... and if I dont come back I want somebody to know.'},
#  {'Quote': 'What are you talking about?'},
#  {'Quote': 'I made some friends at the Academy. ... when our frigate goes to one of the central systems were going to jump ship and join the Alliance...'},
#  {'Quote': 'Join the Rebellion?!  Are you kidding!  How?'},
#  {'Quote': 'Quiet down will ya!  You got a mouth bigger than a meteor crater!'},
#  {'Quote': 'Im sorry.  Im quiet. Listen how quiet I am.  You can barely hear me...'},
#  {'Quote': 'My friend has a friend on Bestine who might help us make contact.'},
#  {'Quote': 'around forever trying to find them.'},
#  {'Quote': 'I know its a long shot but if I dont find them Ill do what I can on my own...  Its what we always talked about.  Luke Im not going to wait for the Empire to draft me into service.  The Rebellion is spreading and I want to be on the right side - the side I believe in. '},
#  {'Quote': 'And Im stuck here...'},
#  {'Quote': 'I thought you were going to the Academy next term.  Youll get your chance to get off this rock.'},
#  {'Quote': 'Not likely!  I had to cancel my application.  There has been a lot of unrest among the Sand People since you left... theyve even raided the outskirts of Anchorhead.'},
#  {'Quote': 'Your uncle could hold off a whole colony of Sand People with one blaster.'},
#  {'Quote': 'I know but hes got enough vaporators going to make the place pay off.  He needs me for just one more season.  I cant leave him now.'},
#  {'Quote': 'I feel for you Luke youre going to have to learn what seems to be important or what really is important.  What good is all your uncles work if its taken over by the Empire?...  You know theyre starting to nationalize commerce in the central systems...it wont be long before your uncle is merely a tenant slaving for the greater glory of the Empire.'},
#  {'Quote': 'It couldnt happen here.  You said it yourself.  The Empire wont bother with this rock.'},
#  {'Quote': 'Things always change.'},
#  {'Quote': 'I wish I was going...  Are you going to be around long? '},
#  {'Quote': 'No Im leaving in the morning...'},
#  {'Quote': 'Then I guess I wont see you.'},
#  {'Quote': 'Maybe someday...  Ill keep a lookout.'},
#  {'Quote': 'Well Ill be at the Academy next season... after that who knows.  I wont be drafted into the Imperial Starfleet thats for sure...  Take care of yourself youll always be the best friend Ive got.'},
#  {'Quote': 'So long Luke.'},
#  {'Quote': 'Artoo-Detoo!  Its you!  Its you!'},
#  {'Quote': 'TROOPER Someone was in the pod.  The tracks go off in this direction. '},
#  {'Quote': 'TROOPER Look sir - droids.'},
#  {'Quote': 'Wake up!  Wake up!'},
#  {'Quote': 'Were doomed.'},
#  {'Quote': 'Do you think theyll melt us down?'},
#  {'Quote': 'Dont shoot!  Dont shoot!  Will this never end?'},
#  {'Quote': 'Luke tell Owen that if he gets a translator to be sure it speaks Bocce.'},
#  {'Quote': 'It looks like we dont have much of a choice but Ill remind him.'},
#  {'Quote': 'I have no need for a protocol droid.'},
#  {'Quote': 'Sir - not in an environment such as this - thats why Ive also been programmed for over thirty secondary functions that...'},
#  {'Quote': 'What I really need is a droid that understands the binary languages of moisture vaporators.'},
#  {'Quote': 'Vaporators!  Sir - My first job was programming binary load lifters... very similar to your vaporators.  You could say...'},
#  {'Quote': 'Do you speak Bocce?'},
#  {'Quote': 'Of course I can sir.  Its like a second language for me...  Im as fluent in Bocce...'},
#  {'Quote': 'All right; shut up! Ill take this one.'},
#  {'Quote': 'Shutting up sir.'},
#  {'Quote': 'Luke take these two over to the garage will you?  I want you to have both of them cleaned up before dinner.'},
#  {'Quote': 'But I was going into Toshi Station to pick up some power converters...'},
#  {'Quote': 'You can waste time with your friends when your chores are done.  Now come on get to it!'},
#  {'Quote': 'All right come on!  And the red one come on.  Well come on Red lets go.'},
#  {'Quote': 'Uncle Owen...'},
#  {'Quote': 'Yeah?'},
#  {'Quote': 'This R2 unit has a bad motivator.  Look!'},
#  {'Quote': 'Hey whatre you trying to push on us?'},
#  {'Quote': 'Excuse me sir but that R2 unit is in prime condition.  A real bargain.'},
#  {'Quote': 'What about that one?'},
#  {'Quote': 'What about that blue one?  Well take that one.'},
#  {'Quote': 'Yeah take it away.'},
#  {'Quote': 'Uh Im quite sure youll be very pleased with that one sir.  He really is in first-class condition.  Ive worked with him before.  Here he comes.'},
#  {'Quote': 'Okay lets go.'},
#  {'Quote': 'Now dont forget this!  Why I should stick my neck out for you is quite beyond my capacity!'},
#  {'Quote': 'Thank the maker!  This oil bath is going to feel so good.  Ive got such a bad case of dust contamination I can barely move!'},
#  {'Quote': 'It just isnt fair.  Oh Biggs is right.  Im never gonna get out of here!'},
#  {'Quote': 'Is there anything I might do to help? '},
#  {'Quote': 'Well not unless you can alter time speed up the harvest or teleport me off this rock!'},
#  {'Quote': 'I dont think so sir.  Im only a droid and not very knowledgeable about such things.  Not on this planet anyways.  As a matter of fact Im not even sure which planet Im on.'},
#  {'Quote': 'Well if theres a bright center to the universe youre on the planet that its farthest from.'},
#  {'Quote': 'I see sir.'},
#  {'Quote': 'Uh you can call me Luke.'},
#  {'Quote': 'I see sir Luke.'},
#  {'Quote': 'Just Luke.'},
#  {'Quote': 'And I am See-Threepio human-cyborg relations and this is my counterpart Artoo-Detoo.'},
#  {'Quote': 'Hello.'},
#  {'Quote': 'You got a lot of carbon scoring here.  It looks like you boys have seen a lot of action.'},
#  {'Quote': 'With all weve been through sometimes Im amazed were in as good condition as we are what with the Rebellion and all.'},
#  {'Quote': 'You know of the Rebellion against the Empire?'},
#  {'Quote': 'Thats how we came to be in your service if you take my meaning sir.'},
#  {'Quote': 'Have you been in many battles?'},
#  {'Quote': 'Several I think.  Actually theres not much to tell.  Im not much more than an interpreter and not very good at telling stories.  Well not at making them interesting anyways.'},
#  {'Quote': 'Well my little friend youve got something jammed in here real good.  Were you on a starcruiser or...'},
#  {'Quote': 'Help me Obi-Wan Kenobi.  Youremy only hope.'},
#  {'Quote': 'Whats this?'},
#  {'Quote': 'What is what?!?  He asked you a question...What is that?'},
#  {'Quote': 'Help me Obi-Wan Kenobi.  Youre my only hope.  Help me Obi-Wan Kenobi.  Youre my only hope.'},
#  {'Quote': 'Oh he says its nothing sir.  Merely a malfunction.  Old data.  Pay it no mind.'},
#  {'Quote': 'Who is she?  Shes beautiful.'},
#  {'Quote': 'Im afraid Im not quite sure sir.'},
#  {'Quote': 'Help me Obi-Wan Kenobi...'},
#  {'Quote': 'I think she was a passenger on our last voyage.  A person of some importance sir - I believe.  Our captain was attached to...'},
#  {'Quote': 'Is there more to this recording?'},
#  {'Quote': 'Behave yourself Artoo.  Youre going to get us in trouble.  Its all right you can trust him.  Hes our new master.'},
#  {'Quote': 'He says hes the property of Obi-Wan Kenobi a resident of these parts.  And its a private message for him.  Quite frankly sir I dont know what hes talking about.  Our last master was Captain Antilles but with what weve been through this little R2 unit has become a bit eccentric.'},
#  {'Quote': 'Obi-Wan Kenobi?  I wonder if he means old Ben Kenobi?'},
#  {'Quote': 'I beg your pardon sir but do you know what hes talking about?'},
#  {'Quote': 'Well I dont know anyone named Obi-Wan but old Ben lives out beyond the dune sea.  Hes kind of a strange old hermit.'},
#  {'Quote': 'I wonder who she is.  It sounds like shes in trouble.  Id better play back the whole thing.'},
#  {'Quote': 'He says the restraining bolt has short circuited his recording system.  He suggests that if you remove the bolt he might be able to play back the entire recording.'},
#  {'Quote': 'Hm?  Oh yeah well I guess youre too small to run away on me if I take this off!  Okay.'},
#  {'Quote': 'There you go.'},
#  {'Quote': 'Well wait a minute.  Whered she go?  Bring her back!  Play back the entire message.'},
#  {'Quote': 'been playing.  The one youre carrying inside your rusty innards! '},
#  {'Quote': 'BERU Luke?  Luke!  Come to dinner!'},
#  {'Quote': 'All right Ill be right there Aunt Beru.'},
#  {'Quote': 'Im sorry sir but he appears to have picked up a slight flutter.'},
#  {'Quote': 'Well see what you can do with him.  Ill be right back.'},
#  {'Quote': 'Just you reconsider playing that message for him.'},
#  {'Quote': 'No I dont think he likes you at all.'},
#  {'Quote': 'No I dont like you either.'},
#  {'Quote': 'You know I think that R2 unit we bought might have been stolen.'},
#  {'Quote': 'What makes you think that?'},
#  {'Quote': 'Well I stumbled across a recording while I was cleaning him.  He says he belongs to someone called Obi-Wan Kenobi.'},
#  {'Quote': 'I thought he might have meant Ben.  Do you know what hes talking about?  Well I wonder if hes related to Ben.'},
#  {'Quote': 'That old mans just a crazy wizard.  Tomorrow I want you to take that R2 unit into Anchorhead and have its memory flushed.  Thatll be the end of it.  It belongs to us now.'},
#  {'Quote': 'But what if this Obi-Wan comes looking for him?'},
#  {'Quote': 'He wont I dont think he exists any more.  He died about the same time as your father.'},
#  {'Quote': 'He knew my father?'},
#  {'Quote': 'I told you to forget it.  Your only concern is to prepare the new droids for tomorrow.  In the morning I want them on the south ridge working out those condensers.'},
#  {'Quote': 'Yes sir.  I think those new droids are going to work out fine.  In fact I uh was also thinking about our agreement about my staying on another season.  And if these new droids do work out I want to transmit my application to the Academy this year.'},
#  {'Quote': 'You mean the next semester before harvest?'},
#  {'Quote': 'Sure therere more than enough droids.'},
#  {'Quote': 'Harvest is when I need you the most.  Only one more season.  This year well make enough on the harvest so Ill be able to hire some more hands.  And then you can go to the Academy next year.'},
#  {'Quote': 'You must understand I need you here Luke.'},
#  {'Quote': 'But its a whole nother year.'},
#  {'Quote': 'Look its only one more season.'},
#  {'Quote': 'Yeah thats what you said last year when Biggs and Tank left.'},
#  {'Quote': 'BERU Where are you going?'},
#  {'Quote': 'It looks like Im going nowhere.  I have to finish cleaning those droids.'},
#  {'Quote': 'BERU Owen he cant stay here forever.  Most of his friends have gone.  It means so much to him.'},
#  {'Quote': 'Ill make it up to him next year.  I promise.'},
#  {'Quote': 'BERU Lukes just not a farmer Owen.  He has too much of his father in him.'},
#  {'Quote': 'Thats what Im afraid of.'},
#  {'Quote': 'What are you doing hiding there?'},
#  {'Quote': 'It wasnt my fault sir.  Please dont deactivate me.  I told him not to go but hes faulty malfunctioning; kept babbling on about his mission.'},
#  {'Quote': 'Oh no!'},
#  {'Quote': 'That R2 unit has always been a problem.  These astro-droids are getting quite out of hand.  Even I cant understand their logic at times. '},
#  {'Quote': 'How could I be so stupid?  Hes nowhere in sight.  Blast it!'},
#  {'Quote': 'Pardon me sir but couldnt we go after him?'},
#  {'Quote': 'Its too dangerous with all the Sand People around.  Well have to wait until morning.'},
#  {'Quote': 'Luke Im shutting the power down for the night.'},
#  {'Quote': 'All right Ill be there in a few minutes.  Boy am I gonna get it.'},
#  {'Quote': 'You know that little droid is going to cause me a lot of trouble.'},
#  {'Quote': 'Oh he excels at that sir.'},
#  {'Quote': 'Luke?  Luke?  Luke?  Where could he be loafing now!'},
#  {'Quote': 'Have you seen Luke this morning?'},
#  {'Quote': 'BERU He said he had some things to do before he started today so he left early.'},
#  {'Quote': 'Uh?  Did he take those two new droids with him?'},
#  {'Quote': 'BERU I think so.'},
#  {'Quote': 'Well hed better have those units in the south range repaired bemidday or therell be hell to pay!'},
#  {'Quote': 'Hows that.'},
#  {'Quote': 'Old Ben Kenobi lives out in this direction somewhere but I dont see how that R2 unit could have come this far.  We must have missed him.  Uncle Owen isnt going to take this very well.'},
#  {'Quote': 'Sir would it help if you told him it was my fault.'},
#  {'Quote': 'Sure.  He needs you.  Hed probably only deactivate you for a day or so...'},
#  {'Quote': 'Deactivate!  Well on the other hand if you hadnt removed his restraining bolt...'},
#  {'Quote': 'Wait theres something dead ahead on the scanner.  It looks like our droid... hit the accelerator.'},
#  {'Quote': 'Hey whoa just where do you think youre going?'},
#  {'Quote': 'Master Luke here is your rightful owner.  Well have no more of this Obi-Wan Kenobi jibberish... and dont talk to me of your mission either.  Youre fortunate he doesnt blast you into a million pieces right here.'},
#  {'Quote': 'Well come on. Its getting late.  I only hope we can get back before Uncle Owen really blows up.'},
#  {'Quote': 'If you dont mind my saying so sir I think you should deactivate the little fugitive until youve gotten him back to your workshop.'},
#  {'Quote': 'No hes not going to try anything.'},
#  {'Quote': 'Whats wrong with him now?'},
#  {'Quote': 'Oh my... sir he says there are several creatures approaching from the southeast.'},
#  {'Quote': 'Sand People!  Or worse!  Come on lets have a look.  Come on.'},
#  {'Quote': 'There are two Banthas down there but I dont see any... wait a second theyre Sand People all right.  I can see one of them now.'},
#  {'Quote': 'Hello there!  Come here my little friend.  Dont be afraid.'},
#  {'Quote': 'Dont worry hell be all right.'},
#  {'Quote': 'What happened?'},
#  {'Quote': 'Rest easy son youve had a busy day.  Youre fortunate youre still in one piece.'},
#  {'Quote': 'Ben?  Ben Kenobi!  Boy am I glad to see you! '},
#  {'Quote': 'The Jundland Wastes are not to be traveled lightly.  Tell me young Luke what brings you out this far?'},
#  {'Quote': 'Oh this little droid!  I think hes searching for his former master...  Ive never seen such devotion in a droid before... there seems tobe no stopping him.  He claims to be the property of an Obi-Wan Kenobi.  Is he a relative of yours?  Do you know who hes talking about?'},
#  {'Quote': 'Obi-Wan Kenobi... Obi-Wan?  Now thats a name I havent heard in a long time... a long time.'},
#  {'Quote': 'I think my uncle knew him.  He said he was dead.'},
#  {'Quote': 'Oh hes not dead no... not yet.'},
#  {'Quote': 'You know him!'},
#  {'Quote': 'Well of course of course I know him.  Hes me!  I havent gone by the name Obi-Wan since oh before you were born.'},
#  {'Quote': 'Then the droid does belong to you.'},
#  {'Quote': 'Dont seem to remember ever owning a droid.  Very interesting... '},
#  {'Quote': 'I think we better get indoors.  The Sand People are easily startled but they will soon be back and in greater numbers.'},
#  {'Quote': '... Threepio!'},
#  {'Quote': 'Where am I?  I must have taken a bad step...'},
#  {'Quote': 'Can you stand?  Weve got to get out of here before the Sand People return.'},
#  {'Quote': 'I dont think I can make it.  You go on Master Luke.  Theres no sense in you risking yourself on my account.  Im done for.'},
#  {'Quote': 'No youre not.  What kind of talk is that?'},
#  {'Quote': 'Quickly son... theyre on the move.'},
#  {'Quote': 'No my father didnt fight in the wars.  He was a navigator on a spice freighter.'},
#  {'Quote': 'Thats what your uncle told you.  He didnt hold with your fathers ideals.  Thought he should have stayed here and not gotten involved.'},
#  {'Quote': 'You fought in the Clone Wars?'},
#  {'Quote': 'Yes I was once a Jedi Knight the same as your father.'},
#  {'Quote': 'I wish Id known him.'},
#  {'Quote': 'He was the best star-pilot in the galaxy and a cunning warrior.  I understand youve become quite a good pilot yourself.  And he was a good friend.  Which reminds me...'},
#  {'Quote': 'I have something here for you.  Your father wanted you to have this when you were old enough but your uncle wouldnt allow it.  He feared you might follow old Obi-Wan on some damned-fool idealistic crusade like your father did. '},
#  {'Quote': 'Sir if youll not be needing me Ill close down for awhile.'},
#  {'Quote': 'Sure go ahead.'},
#  {'Quote': 'What is it?'},
#  {'Quote': 'Your fathers lightsaber.  This is the weapon of a Jedi Knight.  Not as clumsy or as random as a blaster.'},
#  {'Quote': 'An elegant weapon for a morecivilized time.  For over a thousand generations the Jedi Knights were the guardians of peace and justice in the Old Republic.  Before the dark times before the Empire.'},
#  {'Quote': 'How did my father die?'},
#  {'Quote': 'A young Jedi named Darth Vader who was a pupil of mine until he turned to evil helped the Empire hunt down and destroy the Jedi Knights.  He betrayed and murdered your father.  Now the Jedi are all but extinct.  Vader was seduced by the dark side of the Force.'},
#  {'Quote': 'The Force?'},
#  {'Quote': 'Well the Force is what gives the Jedi his power.  Its an energy field created by all living things.  It surrounds us and penetrates us.  It binds the galaxy together.'},
#  {'Quote': 'Now lets see if we cant figure out what you are my little friend.  And where you come from.'},
#  {'Quote': 'I saw part of the message he was...'},
#  {'Quote': 'I seem to have found it.'},
#  {'Quote': 'General Kenobi years ago you served my father in the Clone Wars.  Now he begs you to help him in his struggle against the Empire.  I regret that I am unable to present my fathers request to you in person but my ship has fallen under attack and Im afraid my mission to bring you to Alderaan has failed.  I have placed information vital to the survival of the Rebellion into the memory systems of this R2 unit.  My father will know how to retrieve it.  You must see this droid safely delivered to him on Alderaan.  This is our most desperate hour.  Help me Obi-Wan Kenobi youre my only hope.'},
#  {'Quote': 'You must learn the ways of the Force if youre to come with me to Alderaan.'},
#  {'Quote': 'Alderaan?  Im not going to Alderaan.  Ive got to go home.  Its late Im in for it as it is.'},
#  {'Quote': 'I need your help Luke.  Im getting too old for this sort of thing.She needs your help.'},
#  {'Quote': 'I cant get involved!  Ive got work to do!  Its not that I like the Empire.  I hate it!  But theres nothing I can do about it right now.  Its such a long way from here.'},
#  {'Quote': 'Thats your uncle talking.'},
#  {'Quote': 'Oh God my uncle.  How am I ever going to explain this?'},
#  {'Quote': 'Learn about the Force Luke.'},
#  {'Quote': 'Look I can take you as far as Anchorhead.  You can get a transport there to Mos Eisley or wherever youre going.'},
#  {'Quote': 'You must do what you feel is right of course.'},
#  {'Quote': 'Until this battle station is fully operational we are vulnerable.  The Rebel Alliance is too well equipped.  Theyre more dangerous than you realize.'},
#  {'Quote': 'Dangerous to your starfleet Commander; not to this battle station!'},
#  {'Quote': 'The Rebellion will continue to gain support in the Imperial Senate as long as....'},
#  {'Quote': 'The Imperial Senate will no longer be of any concern to us.  Ive just received word that the Emperor has dissolved the council permanently.  The last remnants of the Old Republic have been swept away.'},
#  {'Quote': 'Thats impossible!  How will the Emperor maintain control without the bureaucracy?'},
#  {'Quote': 'The regional governors now have direct control over territories.  Fear will keep the local systems in line.  Fear of this battle station.'},
#  {'Quote': 'And what of the Rebellion?  If the Rebels have obtained a complete technical readout of this station it is possible however unlikely that they might find a weakness and exploit it.'},
#  {'Quote': 'The plans you refer to will soon be back in our hands.'},
#  {'Quote': 'Any attack made by the Rebels against this station would be a useless gesture no matter what technical data theyve obtained.  This station is now the ultimate power in the universe.  I suggest we use it!'},
#  {'Quote': 'Dont be too proud of this technological terror youve constructed.  The ability to destroy a planet is insignificant next to the power of the Force.'},
#  {'Quote': 'Dont try to frighten us with your sorcerers ways Lord Vader.  Your sad devotion to that ancient religion has not helped you conjure up the stolen data tapes or given you clairvoyance enough to find the Rebels hidden fort...'},
#  {'Quote': 'I find your lack of faith disturbing.'},
#  {'Quote': 'Enough of this!  Vader release him!'},
#  {'Quote': 'As you wish.'},
#  {'Quote': 'This bickering is pointless.  Lord Vader will provide us with the location of the Rebel fortress by the time this station is operational.  We will then crush the Rebellion with one swift stroke.'},
#  {'Quote': 'It looks like Sand People did this all right.  Look here are gaffi sticks bantha tracks.  Its just... I never heard of them hitting anything this big before.'},
#  {'Quote': 'They didnt.  But we are meant to think they did.  These tracks are side by side.  Sand People always ride single file to hide there numbers.'},
#  {'Quote': 'These are the same Jawas that sold us Artoo and Threepio.'},
#  {'Quote': 'And these blast points too accurate for Sand People.  Only Imperial stormtroopers are so precise.'},
#  {'Quote': 'Why would Imperial troops want to slaughter Jawas?'},
#  {'Quote': 'If they traced the robots here they may have learned who they sold them to.  And that would lead them back home!'},
#  {'Quote': 'Wait Luke!  Its too dangerous.'},
#  {'Quote': 'Uncle Owen!  Aunt Beru!  Uncle Owen!'},
#  {'Quote': 'And now Your Highness we will discuss the location of your hidden Rebel base.'},
#  {'Quote': 'Theres nothing you could have done Luke had you been there.  Youd have been killed too and the droids would now be in the hands of the Empire.'},
#  {'Quote': 'I want to come with you to Alderaan.  Theres nothing here for me now.  I want to learn the ways of the Force and become a Jedi like my father.'},
#  {'Quote': 'Mos Eisley Spaceport.  You will never find a more wretched hive of scum and villainy.  We must be cautious.'},
#  {'Quote': 'How long have you had these droids?'},
#  {'Quote': 'About three or four seasons.'},
#  {'Quote': 'Theyre for sale if you want them.'},
#  {'Quote': 'Let me see your identification.'},
#  {'Quote': 'You dont need to see his identification.'},
#  {'Quote': 'We dont need to see his identification.'},
#  {'Quote': 'looking for.'},
#  {'Quote': 'These are not the droids were looking for.'},
#  {'Quote': 'He can go about his business.'},
#  {'Quote': 'You can go about your business.'},
#  {'Quote': 'Move along.'},
#  {'Quote': 'Move along.  Move along.'},
#  {'Quote': 'I cant abide these Jawas.  Disgusting creatures.'},
#  {'Quote': 'Go on go on.  I cant understand how we got by those troopers.  I thought we were dead.'},
#  {'Quote': 'The Force can have a strong influence on the weak-minded.  You will find it a powerful ally.'},
#  {'Quote': 'Do you really think were going to find a pilot here thatll take us to Alderaan?'},
#  {'Quote': 'Well most of the best freighter pilots can be found here.  Only watch your step.  This place can be a little rough.'},
#  {'Quote': 'Im ready for anything.'},
#  {'Quote': 'Come along Artoo.'},
#  {'Quote': 'We dont serve their kind here!'},
#  {'Quote': 'What?'},
#  {'Quote': 'Your droids. Theyll have to wait outside.  We dont want them here.'},
#  {'Quote': 'Listen why dont you wait out by the speeder.  We dont want any trouble.'},
#  {'Quote': 'I heartily agree with you sir.'},
#  {'Quote': 'Negola dewaghi wooldugger?!?'},
#  {'Quote': 'He doesnt like you.'},
#  {'Quote': 'Im sorry.'},
#  {'Quote': 'I dont like you either'},
#  {'Quote': 'Dont insult us.  You just watch yourself.  Were wanted men.  I have the death sentence on twelve systems.'},
#  {'Quote': 'Ill be careful than.'},
#  {'Quote': 'Youll be dead.'},
#  {'Quote': 'This little one isnt worth the effort.  Come let me buy you something...'},
#  {'Quote': 'No blasters!  No blaster!'},
#  {'Quote': 'This is Chewbacca.  Hes first-mate on a ship that might suit our needs.'},
#  {'Quote': 'I dont like the look of this.'},
#  {'Quote': 'Han Solo.  Im captain of the Millennium Falcon.  Chewie here tells me youre looking for passage to the Alderaan system.'},
#  {'Quote': 'Yes indeed.  If its a fast ship.'},
#  {'Quote': 'Fast ship?  Youve never heard of the Millennium Falcon?'},
#  {'Quote': 'Should I have?'},
#  {'Quote': 'Its the ship that made the Kessel run in less than twelve parsecs!'},
#  {'Quote': 'Ive outrun Imperial starships not the local bulk-cruisers mind you.  Im talking about the big Corellian ships now.  Shes fast enough for you old man.  Whats the cargo?'},
#  {'Quote': 'Only passengers.  Myself the boy two droids and no questions asked.'},
#  {'Quote': 'What is it?  Some kind of local trouble?'},
#  {'Quote': 'Lets just say wed like to avoid any Imperial entanglements.'},
#  {'Quote': 'Well thats the real trick isnt it?  And its going to cost you something extra.  Ten thousand in advance.'},
#  {'Quote': 'Ten thousand?  We could almost buy our own ship for that!'},
#  {'Quote': 'But whos going to fly it kid!  You?'},
#  {'Quote': 'You bet I could.  Im not such a bad pilot myself!  We dont have to sit here and listen...'},
#  {'Quote': 'We havent that much with us.  But we could pay you two thousand now plus fifteen when we reach Alderaan.'},
#  {'Quote': 'Seventeen huh!'},
#  {'Quote': 'Okay.  You guys got yourself a ship.  Well leave as soon as youre ready.  Docking bay Ninety-four.'},
#  {'Quote': 'Ninety-four.'},
#  {'Quote': 'Looks like somebodys beginning to take an interest in your handiwork.'},
#  {'Quote': 'All right well check it out.'},
#  {'Quote': 'Seventeen thousand!  Those guys must really be desperate.  This could really save my neck.  Get back to the ship and get her ready.'},
#  {'Quote': 'Youll have to sell your speeder.'},
#  {'Quote': 'Thats okay.  Im never coming back to this planet again.'},
#  {'Quote': 'Going somewhere Solo?'},
#  {'Quote': 'Yes Greedo.  As a matter of fact I was just going to see your boss.  Tell Jabba that Ive got his money.'},
#  {'Quote': 'Its too late.  You should have paid him when you had the chance.  Jabbas put a price on your head so large that every bounty hunter in the galaxy will be looking for you.  Im lucky I found you first.'},
#  {'Quote': 'Yeah but this time I got the money.'},
#  {'Quote': 'If you give it to me I might forget I found you.'},
#  {'Quote': 'I dont have it with me.  Tell Jabba...'},
#  {'Quote': 'Jabbas through with you.  He has no time for smugglers who drop their shipments at the first sign of an Imperial cruiser.'},
#  {'Quote': 'Even I get boarded sometimes.  Do you think I had a choice?'},
#  {'Quote': 'You can tell that to Jabba.  He may only take your ship.'},
#  {'Quote': 'Over my dead body.'},
#  {'Quote': 'Thats the idea Ive been looking forward to killing you for a long time.'},
#  {'Quote': 'Yes Ill bet you have.'},
#  {'Quote': 'Sorry about the mess.'},
#  {'Quote': 'Her resistance to the mind probe is considerable.  It will be some time before we can extract any information from her.'},
#  {'Quote': 'OFFICER The final check-out is complete.  All systems are operational.  What course shall we set?'},
#  {'Quote': 'Perhaps she would respond to an alternative form of persuasion.'},
#  {'Quote': 'What do you mean?'},
#  {'Quote': 'I think it is time we demonstrate the full power of this station.Set your course for Princess Leias home planet of Alderaan.'},
#  {'Quote': 'With pleasure.'},
#  {'Quote': 'Lock the door Artoo.'},
#  {'Quote': 'All right check that side of the street.  Its secure.  Move on to the next door.'},
#  {'Quote': 'I would much rather have gone with Master Luke than stay here with you.  I dont know what all this trouble is about but Im sure it must be your fault.'},
#  {'Quote': 'You watch your language!'},
#  {'Quote': 'He says its the best he can do.  Since the XP-38 came out they '},
#  {'Quote': 'It will be enough.'},
#  {'Quote': 'If the ships as fast as hes boasting we ought to do well.'},
#  {'Quote': 'Come on out Solo!'},
#  {'Quote': 'Ive been waiting for you Jabba.'},
#  {'Quote': 'I expected you would be.'},
#  {'Quote': 'Im not the type to run.'},
#  {'Quote': 'Han my boy there are times when you disappoint me... why havent you paid me?  And why did you have to fry poor Greedo like that... after all weve been through together.'},
#  {'Quote': 'You sent Greedo to blast me.'},
#  {'Quote': 'Han why youre the best smuggler in the business.  Youre too valuable to fry.  He was only relaying my concern at your delays.  He wasnt going to blast you.'},
#  {'Quote': 'I think he thought he was.  Next time dont send one of those twerps.  If youve got something to say to me come see me yourself.'},
#  {'Quote': 'Han Han!  If only you hadnt had to dump that shipment of spice... you understand I just cant make an exception.  Where would I be if every pilot who smuggled for me dumped their shipment at the first sign of an Imperial starship?  Its not good business.'},
#  {'Quote': 'You know even I get boarded sometimes Jabba.  I had no choice but Ive gota charter now and I can pay you back plus a little extra.  I just need some more time.'},
#  {'Quote': 'Put your blasters away.  Han my boy Im only doing this because youre the best and I need you.  So for an extra say... twenty percent Ill give you a little more time... but this is it.  If you disappoint me again Ill put a price on your head so large you wont be able to go near a civilized system for the rest of your short life.'},
#  {'Quote': 'Jabba Ill pay you because its my pleasure.'},
#  {'Quote': 'What a piece of junk.'},
#  {'Quote': 'Shell make point five beyond the speed of light.  She may not look like much but shes got it where it counts kid.  Ive added some special modifications myself.'},
#  {'Quote': 'Were a little rushed so if youll hurry aboard well get out of here.'},
#  {'Quote': 'Hello sir.'},
#  {'Quote': 'Which way?'},
#  {'Quote': 'All right men.  Load your weapons!'},
#  {'Quote': 'Stop that ship!'},
#  {'Quote': 'Blast em!'},
#  {'Quote': 'Chewie get us out of here!'},
#  {'Quote': 'Oh my.  Id forgotten how much I hate space travel.'},
#  {'Quote': 'It looks like an Imperial cruiser.  Our passengers must be hotter than I thought.  Try and hold them off.  Angle the deflector shield while I make the calculations for the jump to light speed.'},
#  {'Quote': 'Stay sharp!  There are two more coming in; theyre going to try to cut us off.'},
#  {'Quote': 'Why dont you outrun them?  I thought you said this thing was fast.'},
#  {'Quote': 'Watch your mouth kid or youre going to find yourself floating home.  Well be safe enough once we make the jump to hyperspace.  Besides I know a few maneuvers. Well lose them!'},
#  {'Quote': 'Heres where the fun begins!'},
#  {'Quote': 'How long before you can make the jump to light speed?'},
#  {'Quote': 'Itll take a few moments to get the coordinates from the navi-computer.'},
#  {'Quote': 'Are you kidding?  At the rate theyre gaining...'},
#  {'Quote': 'Traveling through hyperspace isnt like dusting crops boy!  Without precise calculations we could fly right through a star or bounce too close to a supernova and thatd end your trip real quick wouldnt it?'},
#  {'Quote': 'Whats that flashing?'},
#  {'Quote': 'Were losing our deflector shield.  Go strap yourself in Im going to make the jump to light speed.'},
#  {'Quote': 'Weve entered the Alderaan system.'},
#  {'Quote': 'Governor Tarkin I should have expected to find you holding Vaders leash.  I recognized your foul stench when I was brought on board.'},
#  {'Quote': 'Charming to the last.  You dont know how hard I found it signing the order to terminate your life!'},
#  {'Quote': 'to take the responsibility yourself!'},
#  {'Quote': 'Princess Leia before your execution I would like you to be my guest at a ceremony that will make this battle station operational.  No star system will dare oppose the Emperor now.'},
#  {'Quote': 'The more you tighten your grip Tarkin the more star systems will slip through your fingers.'},
#  {'Quote': 'Not after we demonstrate the power of this station.  In a way you have determined the choice of the planet thatll be destroyed first.  Since you are reluctant to provide us with the location of the Rebel base I have chosen to test this stations destructive power... on your home planet of Alderaan.'},
#  {'Quote': 'No!  Alderaan is peaceful.  We have no weapons.  You cant possibly...'},
#  {'Quote': 'You would prefer another target?  A military target?  Then name the system!'},
#  {'Quote': 'I grow tired of asking this.  So itll be the last time.  Where is the Rebel base?'},
#  {'Quote': 'Dantooine.'},
#  {'Quote': 'Theyre on Dantooine.'},
#  {'Quote': 'There.  You see Lord Vader she can be reasonable. Continue with the operation.  You may fire when ready.'},
#  {'Quote': 'Youre far too trusting.  Dantooine is too remote to make an effective demonstration.  But dont worry.  We will deal with your Rebel friends soon enough. '},
#  {'Quote': 'No!'},
#  {'Quote': 'Commence primary ignition.'},
#  {'Quote': 'Are you all right?  Whats wrong?'},
#  {'Quote': 'I felt a great disturbance in the Force... as if millions of voices suddenly cried out in terror and were suddenly silenced.  I fear something terrible has happened.'},
#  {'Quote': 'Youd better get on with your exercises.'},
#  {'Quote': 'Well you can forget your troubles with those Imperial slugs.  I told you Id outrun em.'},
#  {'Quote': 'Dont everyone thank me at once.'},
#  {'Quote': 'Anyway we should be at Alderaan about oh-two-hundred hours.'},
#  {'Quote': 'Now be careful Artoo.'},
#  {'Quote': 'He made a fair move.  Screaming about it wont help you.'},
#  {'Quote': 'Let him have it. Its not wise to upset a Wookiee.'},
#  {'Quote': 'But sir nobody worries about upsetting a droid.'},
#  {'Quote': 'Thats cause droids dont pull peoples arms out of their socket when they lose.  Wookiees are known to do that.'},
#  {'Quote': 'I see your point sir.  I suggest a new strategy Artoo.  Let the Wookiee win.'},
#  {'Quote': 'Remember a Jedi can feel the Force flowing through him.'},
#  {'Quote': 'You mean it controls your actions?'},
#  {'Quote': 'Partially. But it also obeys your commands.'},
#  {'Quote': 'Hokey religions and ancient weapons are no match for a good blaster at your side kid.'},
#  {'Quote': 'You dont believe in the Force do you?'},
#  {'Quote': 'Kid Ive flown from one side of this galaxy to the other.  Ive seen a lot of strange stuff but Ive never seen anything to make me believe theres one all-powerful force controlling everything.  Theres no mystical energy field that controls my destiny.'},
#  {'Quote': 'Its all a lot of simple tricks and nonsense.'},
#  {'Quote': 'I suggest you try it again Luke.'},
#  {'Quote': 'This time let go your conscious self and act on instinct.'},
#  {'Quote': 'With the blast shield down I cant even see.  How am I supposed to fight?'},
#  {'Quote': 'Your eyes can deceive you.  Dont trust them.'},
#  {'Quote': 'Stretch out with your feelings.'},
#  {'Quote': 'You see you can do it.'},
#  {'Quote': 'I call it luck. '},
#  {'Quote': 'In my experience theres no such thing as luck.'},
#  {'Quote': 'Look going good against remotes is one thing.  Going good against the living?  Thats something else.'},
#  {'Quote': 'Looks like were coming up on Alderaan.'},
#  {'Quote': 'You know I did feel something.  I could almost see the remote.'},
#  {'Quote': 'Thats good.  You have taken your first step into a larger world.'},
#  {'Quote': 'Yes.'},
#  {'Quote': 'CASS Our scout ships have reached Dantooine.  They found the remains of a Rebel base but they estimate that it has been deserted for some time.  They are now conducting an extensive search of the surrounding systems.'},
#  {'Quote': 'She lied!  She lied to us!'},
#  {'Quote': 'I told you she would never consciously betray the Rebellion.'},
#  {'Quote': 'Terminate her... immediately!'},
#  {'Quote': 'Stand by Chewie here we go.  Cut in the sublight engines.'},
#  {'Quote': 'What the...?  Aw weve come out of hyperspace into a meteor shower.  Some kind of asteroid collision.  Its not on any of the charts.'},
#  {'Quote': 'Whats going on?'},
#  {'Quote': 'Our position is correct except... no Alderaan!'},
#  {'Quote': 'What do you mean?  Where is it?'},
#  {'Quote': 'Thats what Im trying to tell you kid.  It aint there.  Its been totally blown away.'},
#  {'Quote': 'What?  How?'},
#  {'Quote': 'Destroyed... by the Empire!'},
#  {'Quote': 'The entire starfleet couldnt destroy the whole planet.  Itd take a thousand ships with more fire power than Ive...'},
#  {'Quote': 'Theres another ship coming in.'},
#  {'Quote': 'Maybe they know what happened.'},
#  {'Quote': 'Its an Imperial fighter.'},
#  {'Quote': 'It followed us!'},
#  {'Quote': 'No.  Its a short range fighter.'},
#  {'Quote': 'There arent any bases around here.  Where did it come from?'},
#  {'Quote': 'It sure is leaving in a big hurry.  If they identify us were in big trouble.'},
#  {'Quote': 'Not if I can help it.  Chewie... jam its transmissions.'},
#  {'Quote': 'Itd be as well to let it go.  Its too far out of range.'},
#  {'Quote': 'Not for long...'},
#  {'Quote': 'A fighter that size couldnt get this deep into space on its own.'},
#  {'Quote': 'Then he must have gotten lost been part of a convoy or something...'},
#  {'Quote': 'Well he aint going to be around long enough to tell anyone about us.'},
#  {'Quote': 'Look at him.  Hes heading for that small moon.'},
#  {'Quote': 'I think I can get him before he gets there... hes almost in range.'},
#  {'Quote': 'Thats no moon!  Its a space station.'},
#  {'Quote': 'Its too big to be a space station.'},
#  {'Quote': 'I have a very bad feeling about this.'},
#  {'Quote': 'Turn the ship around!'},
#  {'Quote': 'Yeah I think your right.  Full reverse!  Chewie lock in the auxiliary power.'},
#  {'Quote': 'Why are we still moving towards it?'},
#  {'Quote': 'Were caught in a tractor beam!  Its pulling us in!'},
#  {'Quote': 'But theres gotta be something you can do!'},
#  {'Quote': 'Theres nothin I can do about it kid.  Im in full power.  Im going to have to shut down.  But theyre not going to get me without a fight!'},
#  {'Quote': 'You cant win.  But there are alternatives to fighting.'},
#  {'Quote': 'OVER DEATH STAR INTERCOM Clear Bay twenty-three-seven.  We are opening the magnetic field.'},
#  {'Quote': 'To your stations!'},
#  {'Quote': 'Come with me.'},
#  {'Quote': 'Close all outboard shields!  Close all outboard shields!'},
#  {'Quote': 'Weve captured a freighter entering the remains of the Alderaan system.  Its markings match those of a ship that blasted its way out of Mos Eisley.'},
#  {'Quote': 'They must be trying to return the stolen plans to the princess.  She may yet be of some use to us.'},
#  {'Quote': 'Unlock one-five-seven and nine. Release charges.'},
#  {'Quote': 'Theres no one on board sir.  According to the log the crew abandoned ship right after takeoff.  It must be a decoy sir.  Several of the escape pods have been jettisoned.'},
#  {'Quote': 'Did you find any droids?'},
#  {'Quote': 'No sir.  If there were any on board they must also have jettisoned.'},
#  {'Quote': 'Send a scanning crew on board.  I want every part of this ship checked.'},
#  {'Quote': 'I sense something... a presence I havent felt since...'},
#  {'Quote': 'Get me a scanning crew in here on the double.  I want every part of this ship checked!'},
#  {'Quote': 'Boy its lucky you had these compartments.'},
#  {'Quote': 'I use them for smuggling.  I never thought Id be smuggling myself in them.  This is ridiculous.  Even if I could take off Id never get past the tractor beam.'},
#  {'Quote': 'Leave that to me!'},
#  {'Quote': 'Damn fool. I knew that you were going to say that!'},
#  {'Quote': 'Whos the more foolish... the fool or the fool who follows him?'},
#  {'Quote': 'The ships all yours.  If the scanners pick up anything report it immediately.  All right lets go.'},
#  {'Quote': 'Hey down there could you give us a hand with this?'},
#  {'Quote': 'OFFICER TX-four-one-two.  Why arent you at your post?  TX-four-one-two do you copy? '},
#  {'Quote': 'OFFICER Take over.  Weve got a bad transmitter.  Ill see what I can do.'},
#  {'Quote': 'You know between his howling and your blasting everything in sight its a wonder the whole station doesnt know were here.'},
#  {'Quote': 'Bring them on!  I prefer a straight fight to all this sneaking around.'},
#  {'Quote': 'We found the computer outlet sir.'},
#  {'Quote': 'Plug in.  He should be able to interpret the entire Imperial computer network.'},
#  {'Quote': 'He says hes found the main control to the power beam thats holding the ship here.  Hell try to make the precise location appear on the monitor.'},
#  {'Quote': 'The tractor beam is coupled to the main reactor in seven locations.  A power loss at one of the terminals will allow the ship to leave.'},
#  {'Quote': 'I dont think you boys can help.  I must go alone.'},
#  {'Quote': 'Whatever you say.  Ive done more than I bargained for on this trip already.'},
#  {'Quote': 'I want to go with you.'},
#  {'Quote': 'Be patient Luke.  Stay and watch over the droids.'},
#  {'Quote': 'But he can...'},
# ...
#  {'Quote': 'That doesnt sound too hard.  Besides they let us go.  Its the only explanation for the ease of our escape.'},
#  {'Quote': 'Easy... you call that easy?'},
#  {'Quote': 'Their tracking us!'},
#  {'Quote': 'Not this ship sister.'},
#  {'Quote': 'At least the information in Artoo is still intact.'},
#  {'Quote': 'Whats so important?  Whats he carrying?'},
#  {'Quote': 'The technical readouts of that battle station.  I only hope that when the data is analyzed a weakness can be found.  Its not over yet!'},
#  {'Quote': 'It is for me sister!  Look I aint in this for your revolution and Im not in it for you Princess.  I expect to be well paid.  Im in it for the money!'},
#  {'Quote': 'You neednt worry about your reward.  If money is all that you love then thats what youll receive!'},
#  {'Quote': 'Your friend is quite a mercenary.  I wonder if he really cares about anything... or anyone.'},
#  {'Quote': 'I care!'},
#  {'Quote': 'So... what do you think of her Han?'},
#  {'Quote': 'Im trying not to kid!'},
#  {'Quote': 'Good...'},
#  {'Quote': 'Still shes got a lot of spirit.  I dont know what do you think?  Do you think a princess and a guy like me...'},
#  {'Quote': 'Youre safe!  We had feared the worst.'},
#  {'Quote': 'When we heard about Alderaan we were afraid that you were... lost along with your father.'},
#  {'Quote': 'We dont have time for our sorrows commander.  The battle station has surely tracked us here.Its the only explanation for the ease of our escape.  You must use the information in this R2 unit to plan the attack.  It is our only hope.'},
#  {'Quote': 'STAR INTERCOM VOICE We are approaching the planet Yavin.  The Rebel base is on a moon on the far side.  We are preparing to orbit the planet.'},
#  {'Quote': 'The battle station is heavily shielded and carries a firepower greater than half the star fleet.Its defenses are designed around a direct large-scale assault.  A small one-man fighter should be able to penetrate the outer defense.'},
#  {'Quote': 'LEADER Pardon me for asking sir but what good are snub fighters going to be against that?'},
#  {'Quote': 'Well the Empire doesnt consider a small one-man fighter to be any threat or theyd have a tighter defense.  An analysis of the plans provided by Princess Leia has demonstrated a weakness in the battle station.'},
#  {'Quote': 'The approach will not be easy.  You are required to maneuver straight down this trench and skim the surface to this point.  The target area is only two meters wide.  Its a small thermal exhaust port right below the main port.  The shaft leads directly to the reactor system.  A precise hit will start a chain reaction which should destroy the station.'},
#  {'Quote': 'Only a precise hit will set up a chain reaction.  The shaft is ray-shielded so youll have to use proton torpedoes.'},
#  {'Quote': 'Thats impossible even for a computer.'},
#  {'Quote': 'Its not impossible.  I used to bullseye womp rats in my T-sixteen back home.  Theyre not much bigger than two meters.'},
#  {'Quote': 'Man your ships!  And may the Force be with you!'},
#  {'Quote': 'STAR INTERCOM VOICE Orbiting the planet at maximum velocity.  The moon with the Rebel base will be in range in thirty minutes.'},
#  {'Quote': 'This will be a day long remembered.  It has seen the end of Kenobi and it will soon see the end of the Rebellion.'},
#  {'Quote': 'All flight troops man your stations.  All flight troops man your stations.'},
#  {'Quote': 'So... you got your reward and youre just leaving then?'},
#  {'Quote': 'Thats right yeah!  I got some old debts Ive got to pay off with this stuff.  Even if I didnt you dont think Id be fool enough to stick around here do you?  Why dont you come with us?  Youre pretty good in a fight.  I could use you.'},
#  {'Quote': 'Come on!  Why dont you take a look around?  You know whats about to happen what theyre up against.  They could use a good pilot like you.  Youre turning your back on them.'},
#  {'Quote': 'What goods a reward if you aint around to use it?  Besides attacking that battle station aintmy idea of courage.  Its more like suicide.'},
#  {'Quote': 'All right.  Well take care of yourself Han... guess thats what youre best at isnt it?'},
#  {'Quote': 'Hey Luke... may the Force be with you!'},
#  {'Quote': 'Whatre you lookin at?  I know what Im doing.'},
#  {'Quote': 'Whats wrong?'},
#  {'Quote': 'Oh its Han!  I dont know I really thought hed change his mind. '},
#  {'Quote': 'Hes got to follow his own path.  No one can choose it for him.'},
#  {'Quote': 'I only wish Ben were here.'},
#  {'Quote': 'Luke!  I dont believe it!  Howd you get here... are you going out with us?!'},
#  {'Quote': 'Biggs!  Of course Ill be up there with you!  Listen have I got some stories to tell...'},
#  {'Quote': 'LEADER Are you... Luke Skywalker?  Have you been checked out on the Incom T-sixty-five?'},
#  {'Quote': 'Sir Luke is the best bushpilot in the outer rim territories.'},
#  {'Quote': 'LEADER I met your father once when I was just a boy.  He was a great pilot.  Youll do all right.  If youve got half of your fathers skill youll do better than all right.'},
#  {'Quote': 'Thank you sir.  Ill try.'},
#  {'Quote': 'Ive got to get aboard.  Listen youll tell me your stories when we come back.  All right?'},
#  {'Quote': 'I told you Id make it someday Biggs.'},
#  {'Quote': 'You did all right.  Its going to be like old times Luke. Were a couple of shooting stars thatll never be stopped!'},
#  {'Quote': 'This R2 unit of your seems a bit beat up.  Do you want a new one?'},
#  {'Quote': 'Not on your life!  That little droid and I have been through a lot together.You okay Artoo?'},
#  {'Quote': 'Okay easy she goes!'},
#  {'Quote': 'Hang on tight Artoo youve got to come back.'},
#  {'Quote': 'You wouldnt want my life to get boring would you?'},
#  {'Quote': 'Luke the Force will be with you.'},
#  {'Quote': 'INTERCOM VOICE Stand-by alert.  Death Star approaching.  Estimated time to firing range fifteen minutes.'},
#  {'Quote': 'LEADER All wings report in.'},
#  {'Quote': 'TEN Red Ten standing by.'},
#  {'Quote': 'SEVEN Red Seven standing by.'},
#  {'Quote': 'Red Three standing by.'},
#  {'Quote': 'Red Six standing by.'},
#  {'Quote': 'NINE Red Nine standing by.'},
#  {'Quote': 'Red Two standing by.'},
#  {'Quote': 'ELEVEN Red Eleven standing by.'},
#  {'Quote': 'Red Five standing by.'},
#  {'Quote': 'LEADER Lock S-foils in attack position.'},
#  {'Quote': 'LEADER Were passing through their magnetic field.'},
#  {'Quote': 'LEADER Hold tight!'},
#  {'Quote': 'LEADER Switch your deflectors on.'},
#  {'Quote': 'LEADER Double front!'},
#  {'Quote': 'Look at the size of that thing!'},
#  {'Quote': 'LEADER Cut the chatter Red Two.'},
#  {'Quote': 'LEADER Accelerate to attack speed.  This is it boys!'},
#  {'Quote': 'LEADER Red Leader this is Gold Leader.'},
#  {'Quote': 'LEADER I copy Gold Leader.'},
#  {'Quote': 'LEADER Were starting for the target shaft now.'},
#  {'Quote': 'LEADER Were in position.  Im going to cut across the axis and try and draw their fire.'},
#  {'Quote': 'Heavy fire boss!  Twenty-threedegrees.'},
#  {'Quote': 'LEADER I see it.  Stay low. '},
#  {'Quote': 'This is Red Five!  Im going in!'},
#  {'Quote': 'Luke pull up!'},
#  {'Quote': 'Are you all right?'},
#  {'Quote': 'I got a little cooked but Im okay.'},
#  {'Quote': 'We count thirty Rebel ships Lord Vader.  But theyre so small theyre evading our turbo-lasers!'},
#  {'Quote': 'Well have to destroy them ship to ship.  Get the crews to their fighters.'},
#  {'Quote': 'LEADER Luke let me know when youre going in.'},
#  {'Quote': 'Im on my way in now...'},
#  {'Quote': 'LEADER Watch yourself!  Theres a lot of fire coming from the right side of that deflection tower.'},
#  {'Quote': 'Im on it.'},
#  {'Quote': 'OFFICER Squad leaders weve picked up a new group of signals.  Enemy fighters coming your way.'},
#  {'Quote': 'My scopes negative.  I dont see anything.'},
#  {'Quote': 'LEADER Keep up your visual scanning.  With all this jamming theyll be on top of you before your scope can pick them up.'},
#  {'Quote': 'LEADER Biggs!  Youve picked one up... watch it!'},
#  {'Quote': 'I cant see it!  Where is he?!'},
#  {'Quote': 'Hes on me tight I cant shake him... I cant shake him.'},
#  {'Quote': 'Hang on Biggs Im coming in.'},
#  {'Quote': 'Got him!'},
#  {'Quote': 'Several fighters have broken off from the main group.  Come with me!'},
#  {'Quote': 'Pull in!  Luke... pull in!'},
#  {'Quote': 'Watch your back Luke!'},
#  {'Quote': 'Watch your back!  Fighters above you coming in!'},
#  {'Quote': 'Im hit but not bad.'},
#  {'Quote': 'Artoo see what you can do with it.  Hang on back there.'},
#  {'Quote': 'LEADER Red Six...'},
#  {'Quote': 'LEADER Can you see Red Five?'},
#  {'Quote': 'TEN Theres a heavy fire zone on this side. Red Five where are you?'},
#  {'Quote': 'I cant shake him!'},
#  {'Quote': 'Im on him Luke!'},
#  {'Quote': 'Hold on!'},
#  {'Quote': 'Blast it!  Wedge where are you?'},
#  {'Quote': 'Thanks Wedge.'},
#  {'Quote': 'Good shooting Wedge!'},
#  {'Quote': 'LEADER Red Leader...'},
#  {'Quote': 'LEADER ... This is Gold Leader.  Were starting out attack run.'},
#  {'Quote': 'LEADER I copy Gold Leader.  Move into position.'},
#  {'Quote': 'Stay in attack formation!'},
#  {'Quote': 'LEADER The exhaust post is...'},
#  {'Quote': 'LEADER ... marked and locked in!'},
#  {'Quote': 'LEADER Switch power to front deflection screens.'},
#  {'Quote': 'LEADER How many guns do you think Gold Five?'},
#  {'Quote': 'FIVE Id say about twenty guns.  Some on the surface some on the towers.'},
#  {'Quote': 'INTERCOM VOICE Death Star will be in range in five minutes. '},
#  {'Quote': 'LEADER Switch to targeting computer.'},
#  {'Quote': 'TWO Computers locked.  Getting a signal.'},
#  {'Quote': 'TWO The guns... theyve stopped!'},
#  {'Quote': 'FIVE Stabilize your rear deflectors.  Watch for enemy fighters.'},
#  {'Quote': 'LEADER Theyve coming in!  Three marks at two ten.'},
#  {'Quote': 'Ill take them myself!  Cover me!'},
#  {'Quote': 'LEADER I cant maneuver!'},
#  {'Quote': 'FIVE Stay on target.'},
#  {'Quote': 'LEADER Were too close.'},
#  {'Quote': 'FIVE Stay on target!'},
#  {'Quote': 'LEADER Loosen up!'},
#  {'Quote': 'FIVE Gold Five to Red Leader...'},
#  {'Quote': 'FIVE Lost Tiree lost Dutch.'},
#  {'Quote': 'LEADER I copy Gold Five.'},
#  {'Quote': 'FIVE They came from behind....'},
#  {'Quote': 'Weve analyzed their attack sir and there is a danger.  Should I have your ship standing by?'},
#  {'Quote': 'Evacuate?  In out moment of triumph?  I think you overestimate their chances!'},
#  {'Quote': 'Rebel base three minutes and closing.'},
#  {'Quote': 'LEADER Red Group this is Red Leader.'},
#  {'Quote': 'LEADER Rendezvous at mark six point one.'},
#  {'Quote': 'This is Red Two.  Flying towards you.'},
#  {'Quote': 'Red Leader this is Base One.  Keep half your group out of range for the next run.'},
#  {'Quote': 'LEADER Copy Base One.  Luke take Red Two and Three.  Hold up here and wait for my signal... to start your run.'},
#  {'Quote': 'LEADER This is it!'},
#  {'Quote': 'TEN We should be able to see it by now.'},
#  {'Quote': 'LEADER Keep your eyes open for those fighters!'},
#  {'Quote': 'TEN Theres too much interference!'},
#  {'Quote': 'TEN Red Five can you see them from where you are?'},
#  {'Quote': 'No sign of any... wait!'},
#  {'Quote': 'Coming in point three five.'},
#  {'Quote': 'TEN I see them.'},
#  {'Quote': 'LEADER Im in range.'},
#  {'Quote': 'LEADER Targets coming up!'},
#  {'Quote': 'LEADER Just hold them off for a few seconds.'},
#  {'Quote': 'Close up formation.'},
#  {'Quote': 'LEADER Almost there!'},
#  {'Quote': 'TEN Youd better let her loose.'},
#  {'Quote': 'TEN I cant hold them!'},
#  {'Quote': 'LEADER Its away!'},
#  {'Quote': 'NINE Its a hit!'},
#  {'Quote': 'LEADER Negative.'},
#  {'Quote': 'LEADER Negative!  It didnt go in it just impacted on the surface.'},
#  {'Quote': 'Red Leader were right above you.  Turn to point...'},
#  {'Quote': '... oh-five; well cover for you.'},
#  {'Quote': 'LEADER Stay there...'},
#  {'Quote': 'LEADER ... I just lost my starboard engine.'},
#  {'Quote': 'LEADER Get set up for your attack run.'},
#  {'Quote': 'STAR INTERCOM VOICE Rebel base one minute and closing.'},
#  {'Quote': 'Biggs Wedge lets close it up.  Were going in.  Were going in full throttle.'},
#  {'Quote': 'Right with you boss.'},
#  {'Quote': 'Luke at that speed will you be able to pull out in time?'},
#  {'Quote': 'Itll be just like Beggars Canyon back home.'},
#  {'Quote': 'Well stay back far enough to cover you.'},
#  {'Quote': 'My scope shows the tower but I cant see the exhaust port!  Are you sure the computer can hit it?'},
#  {'Quote': 'Watch yourself!  Increase speed full throttle!'},
#  {'Quote': 'What about that tower?'},
#  {'Quote': 'You worry about those fighters!  Ill worry about the tower!'},
#  {'Quote': 'Artoo... that that stabilizers broken loose again!  See if you cant lock it down!'},
#  {'Quote': 'Im hit!  I cant stay with you.'},
#  {'Quote': 'Get clear Wedge.'},
#  {'Quote': 'You cant do any more good back there!'},
#  {'Quote': 'Sorry!'},
#  {'Quote': 'Let him go!  Stay on the leader!'},
#  {'Quote': 'Hurry Luke theyre coming in much faster this time. I cant hold them!'},
#  {'Quote': 'Artoo try and increase the power!'},
#  {'Quote': 'Hurry up Luke!'},
#  {'Quote': 'Wait!'},
#  {'Quote': 'STAR INTERCOM VOICE Rebel base thirty seconds and closing.'},
#  {'Quote': 'Im on the leader.'},
#  {'Quote': 'Hang on Artoo!'},
#  {'Quote': 'Use the Force Luke.'},
#  {'Quote': 'Let go Luke.'},
#  {'Quote': 'The Force is strong with this one!'},
#  {'Quote': 'Luke trust me.'},
#  {'Quote': 'VOICE His computers off.  Luke you switched off your targeting computer.  Whats wrong?'},
#  {'Quote': 'Nothing.  Im all right.'},
#  {'Quote': 'Ive lost Artoo!'},
#  {'Quote': 'INTERCOM VOICE The Death Star has cleared the planet.  The Death Star has cleared the planet.'},
#  {'Quote': 'STAR INTERCOM VOICE Rebel base in range.'},
#  {'Quote': 'You may fire when ready.'},
#  {'Quote': 'STAR INTERCOM VOICE Commence primary ignition.'},
#  {'Quote': 'I have you now.'},
#  {'Quote': 'Yahoo!'},
#  {'Quote': 'Look out!'},
#  {'Quote': 'Youre all clear kid.'},
#  {'Quote': 'Now lets blow this thing and go home!'},
#  {'Quote': 'VOICE Stand by to fire at Rebel base.'},
#  {'Quote': 'VOICE Standing by.'},
#  {'Quote': 'Great shot kid.  That was one in a million.'},
#  {'Quote': 'Remember the Force will be with you... always.'},
#  {'Quote': 'Hey!  Hey!'},
#  {'Quote': 'I knew youd come back!  I just knew it!'},
#  {'Quote': 'Well I wasnt gonna let you get all the credit and take all the reward.'},
#  {'Quote': 'Hey I knew there was more to you than money.'},
#  {'Quote': 'Oh my!  Artoo!  Can you hear me?  Say something!You can repair him cant you?'},
#  {'Quote': 'Well get to work on him right away.'},
#  {'Quote': 'You must repair him!  Sir if any of my circuits or gears will help Ill gladly donate them.'},
#  {'Quote': 'Hell be all right.'},
#  {'Quote': 'Echo Three to Echo Seven. Han old buddy do you  read me?'},
#  {'Quote': 'Loud and clear kid. Whats up?'},
#  {'Quote': 'Well I finished my circle. I dont pick up any  life readings.'},
#  {'Quote': 'There isnt enough life on this ice cube to fill a  space cruiser. The sensors are placed. Im going back.'},
#  {'Quote': 'Right. Ill see you shortly. Theres a meteorite  that hit the ground near here. I want to check it out. It wont take long.'},
#  {'Quote': 'Hey steady girl. Whats the matter? You smell something?'},
#  {'Quote': 'Aaargh!'},
#  {'Quote': 'All right dont lose your temper. Ill come right back and give  you a hand.'},
#  {'Quote': 'Solo?'},
#  {'Quote': 'No sign of life out there General. The sensors are in place.  Youll know if anything comes around.'},
#  {'Quote': 'Commander Skywalker reported in yet?'},
#  {'Quote': 'No. Hes checking out a meteorite that hit near him.'},
#  {'Quote': 'With all the meteor activity in this  system its going to be difficult to spot approaching ships.'},
#  {'Quote': 'General Ive got to leave. I cant stay anymore.'},
#  {'Quote': 'Im sorry to hear that.'},
#  {'Quote': 'Well theres a price on my head. If I dont pay off Jabba the  Hut Im a dead man.'},
#  {'Quote': 'A death marks not an easy thing to live with. Youre a good  fighter Solo. I hate to lose you.'},
#  ...]

# %%
analyser.polarity_scores('The kid is happy at school')['compound']
# Out:
# 0.5719

# %%
def polarity(character):
    query = list(engine.execute(f"""SELECT `Name`, `Dialogue`.`Dialogue`
    FROM `Starwars`.`Character`
    INNER JOIN `Dialogue`
    ON `idCharacter` = `Character_idCharacter`
    WHERE `Name` = '{character}';"""))
    x = [analyser.polarity_scores(i[1])['compound'] for i in query]
    
    if np.mean(x) >= .05:
        return {'Positive':round(np.mean(x),3)}
    elif np.mean(x) <= -.05:
        return {'Negative':round(np.mean(x),3)}
    else:
        return {'Neutral':round(np.mean(x),3)}

# %%
polarity('HAN')
# Out:
# {'Positive': 0.102}

# %%
### POST

# %%
def check(column,string):
    """
    Función parametrizada que comprueba en cada tabla si existe el user, artista o canción.
    Devuelve True si existe y False si no
    
    que == df_col name
    str == value de la columna. Lo que se inserta en mysql
    chekea si ya existe en mysql
    """
    if column == "character":
        query = list(engine.execute(f"SELECT `Name` FROM `Starwars`.`Character` WHERE `Name` = '{string}';"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif column == "dialogue":
        query = list(engine.execute(f"SELECT `Dialogue` FROM `Starwars`.`Dialogue` WHERE `Dialogue` = '{string}';"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif column == "episode":
        query = list(engine.execute(f"SELECT `Name` FROM `Starwars`.`Episode` WHERE `Name` = '{string}';"))
        if len(query) > 0:
            return True
        else:
            return False

# %%
check('character', 'PEPE')
# Out:
# False

# %%
def insertCharacter(string):
    if check ('character', string):
        return 'Character already exists'
    else:
        engine.execute(f"INSERT INTO `character`.`name` VALUES '{string}';")

# %%
insertCharacter('VADER')
# Out:
# 'Character already exists'
